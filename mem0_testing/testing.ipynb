# %%
from mem0 import MemoryClient, Memory

from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
config = {
    "vector_store": {
        "provider": "qdrant",
        "config": {
            "collection_name": "mem0-testing",
            "url": "https://59620bcb-b9e8-44c6-abcb-9f3780002b11.eu-west-1-0.aws.cloud.qdrant.io",
            "api_key": "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY2Nlc3MiOiJtIn0.O6mSAhN3YrXwYoXgQz6TDCt20DjV8Ve_nHXyHr31uw0",
        }
    }
}

# client = MemoryClient(api_key=os.getenv("MEM0_API_KEY")).from_config(config)
client = Memory().from_config(config)

# %%
client

# %%
query = "do you remember the speaker i asked about before?"

# %%
user_id = "user_skh"
run_id = "session_002"

# %%
global_memories = client.search(
                    query, 
                    user_id=user_id,
                    limit=10
                )

# %%
global_memories
# Out:
# {'results': [{'id': '58d41024-e890-421d-8d2d-9932821ecd88',
#    'memory': 'There is a speaker named Rohan Rao at DataHack Summit 2025',
#    'hash': 'd052eabd740160a429098330d4ba6d67',
#    'metadata': None,
#    'score': 0.2974602,
#    'created_at': '2026-02-16T04:54:28.861696-08:00',
#    'updated_at': None,
#    'user_id': 'user_skh',
#    'run_id': 'session_001'},
#   {'id': '6b12dfe9-69e8-46bd-8384-d405e7eb2803',
#    'memory': 'Interested in DataHack Summit (DHS) 2025 in Bangalore, India',
#    'hash': '6496946586fc719ecae7632296ee2b8a',
#    'metadata': None,
#    'score': 0.14702101,
#    'created_at': '2026-02-16T22:28:42.264976-08:00',
#    'updated_at': None,
#    'user_id': 'user_skh',
#    'run_id': 'session_002'},
#   {'id': '221391fe-4cac-4926-b369-01ad9432ffbe',
#    'memory': "Rohan Rao's bio is Veteran ML professional with extensive experience in data science and building AI/ML products across industries",
#    'hash': '6effaf8f9abc94ce42bf92fffe2654f5',
#    'metadata': None,
#    'score': 0.12363335,
#    'created_at': '2026-02-16T04:54:30.283353-08:00',
#    'updated_at': None,
#    'user_id': 'user_skh',
#    'run_id': 'session_001'},
#   {'id': 'bf57dbfb-2bfd-4bf2-923b-5355c5e0ce5f',
#    'memory': "Rohan Rao's designation is Gen AI Expert",
#    'hash': 'fb0f29b4fad35c5927b8c04a24d63e54',
#    'metadata': None,
#    'score': 0.105851576,
#    'created_at': '2026-02-16T04:54:29.564349-08:00',
#    'updated_at': None,
#    'user_id': 'user_skh',
#    'run_id': 'session_001'},
#   {'id': '52381804-623d-4440-a211-9e5b91a241f2',
#    'memory': 'Rohan Rao is self employed',
#    'hash': '9b1fe2ad20eb90ae48ddb97633846e79',
#    'metadata': None,
#    'score': 0.08902581,
#    'created_at': '2026-02-16T04:54:29.883674-08:00',
#    'updated_at': None,
#    'user_id': 'user_skh',
#    'run_id': 'session_001'}]}

# %%
session_based_memories = client.search(
                query, 
                user_id=user_id,
                run_id=run_id
            )

# %%
session_based_memories
# Out:
# {'results': [{'id': '6b12dfe9-69e8-46bd-8384-d405e7eb2803',
#    'memory': 'Interested in DataHack Summit (DHS) 2025 in Bangalore, India',
#    'hash': '6496946586fc719ecae7632296ee2b8a',
#    'metadata': None,
#    'score': 0.14702101,
#    'created_at': '2026-02-16T22:28:42.264976-08:00',
#    'updated_at': None,
#    'user_id': 'user_skh',
#    'run_id': 'session_002'}]}
